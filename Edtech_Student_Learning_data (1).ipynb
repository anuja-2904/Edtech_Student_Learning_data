# %%
import pandas as pd

# %%
#1. Load the dataset into a Pandas DataFrame.

df = pd.read_csv("Downloads/edtech_student_learning_data.csv")

# %%
#2. Display the first 10 records of the dataset.

df.head(10)
# Out:
#    student_id student_name  gender       city enrollment_date          course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25   Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29         AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05    Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09         AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03   Generative AI
# 5        1006    Student_6  Female       Pune      2024-09-18   Generative AI
# 6        1007    Student_7    Male     Mumbai      2024-02-22  Data Analytics
# 7        1008    Student_8    Male    Chennai      2024-07-23    Data Science
# 8        1009    Student_9    Male     Mumbai      2024-05-05         AI & ML
# 9        1010   Student_10  Female      Delhi      2024-08-22  Data Analytics
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  \
# ...

# %%
#3. Display the last 5 records of the dataset.

df.tail()
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 500        1452  Student_452  Female     Mumbai      2024-03-07
# 501        1276  Student_276  Female  Hyderabad      2024-10-15
# 502        1210  Student_210    Male  Bangalore      2024-04-04
# 503        1178  Student_178    Male      Delhi      2024-01-20
# 504        1397  Student_397  Female     Mumbai      2024-05-27
#
#             course batch_type  total_sessions  sessions_attended  \
# 500  Generative AI    Weekday             120                 68
# 501  Generative AI    Weekday             120                 95
# 502        AI & ML    Weekday             120                 75
# 503  Generative AI    Weekday             120                 80
# 504  Generative AI    Weekend             120                101
#
#      avg_quiz_score  assignment_score  project_score  final_rating  \
# 500              84                84             58           2.2
# ...

# %%
#4. Check the shape of the dataset.

df.shape
# Out:
# (505, 18)

# %%
#5. Display all column names along with their data types.

df.dtypes
# Out:
# student_id             int64
# student_name          object
# gender                object
# city                  object
# enrollment_date       object
# course                object
# batch_type            object
# total_sessions         int64
# sessions_attended      int64
# avg_quiz_score         int64
# assignment_score       int64
# project_score          int64
# final_rating         float64
# learning_hours         int64
# placement_status      object
# feedback_score         int64
# attendance_pct       float64
# salary_offered       float64
# dtype: object

# %%
#6. Generate summary statistics for all numerical columns.

df.describe()
# Out:
#         student_id  total_sessions  sessions_attended  avg_quiz_score  \
# count   505.000000           505.0         505.000000      505.000000
# mean   1251.015842           120.0          88.102970       69.601980
# std     144.242011             0.0          17.087232       17.137226
# min    1001.000000           120.0          60.000000       40.000000
# 25%    1127.000000           120.0          73.000000       56.000000
# 50%    1251.000000           120.0          88.000000       69.000000
# 75%    1376.000000           120.0         103.000000       84.000000
# max    1500.000000           120.0         119.000000       99.000000
#
#        assignment_score  project_score  final_rating  learning_hours  \
# count        505.000000     505.000000    477.000000      505.000000
# mean          71.984158      75.287129      3.535220       22.128713
# std           15.777337      14.678794      0.862365        9.924180
# ...

# %%
#7. Identify columns that contain missing values.

df.isna().sum()
# Out:
# student_id             0
# student_name           0
# gender                 0
# city                   0
# enrollment_date        0
# course                 0
# batch_type             0
# total_sessions         0
# sessions_attended      0
# avg_quiz_score         0
# assignment_score       0
# project_score          0
# final_rating          28
# learning_hours         0
# placement_status       0
# feedback_score         0
# attendance_pct         0
# salary_offered       169
# dtype: int64

# %%
#8. Count the number of missing values in each column.

df.isna().sum()
# Out:
# student_id             0
# student_name           0
# gender                 0
# city                   0
# enrollment_date        0
# course                 0
# batch_type             0
# total_sessions         0
# sessions_attended      0
# avg_quiz_score         0
# assignment_score       0
# project_score          0
# final_rating          28
# learning_hours         0
# placement_status       0
# feedback_score         0
# attendance_pct         0
# salary_offered       169
# dtype: int64

# %%
#9. Calculate the percentage of missing values in the final_rating column

print(df['final_rating'].isnull().sum()/len(df) * 100)
# Out:
# 5.544554455445545

# %%
#10. Fill missing values in the final_rating column using the mean.

df["final_rating"].fillna(df["final_rating"].mean(), inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14552\2269581740.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["final_rating"].fillna(df["final_rating"].mean(), inplace=True)

# %%
#11. Verify that missing values in final_rating are handled.

df.isna().sum()
# Out:
# student_id             0
# student_name           0
# gender                 0
# city                   0
# enrollment_date        0
# course                 0
# batch_type             0
# total_sessions         0
# sessions_attended      0
# avg_quiz_score         0
# assignment_score       0
# project_score          0
# final_rating           0
# learning_hours         0
# placement_status       0
# feedback_score         0
# attendance_pct         0
# salary_offered       169
# dtype: int64

# %%
#12. Check whether duplicate records exist in the dataset.

df.duplicated().sum()
# Out:
# 5

# %%
#13. Count the total number of duplicate rows

df.duplicated().sum()
# Out:
# 5

# %%
#14. Display all duplicate records

df[df.duplicated()]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 500        1452  Student_452  Female     Mumbai      2024-03-07
# 501        1276  Student_276  Female  Hyderabad      2024-10-15
# 502        1210  Student_210    Male  Bangalore      2024-04-04
# 503        1178  Student_178    Male      Delhi      2024-01-20
# 504        1397  Student_397  Female     Mumbai      2024-05-27
#
#             course batch_type  total_sessions  sessions_attended  \
# 500  Generative AI    Weekday             120                 68
# 501  Generative AI    Weekday             120                 95
# 502        AI & ML    Weekday             120                 75
# 503  Generative AI    Weekday             120                 80
# 504  Generative AI    Weekend             120                101
#
#      avg_quiz_score  assignment_score  project_score  final_rating  \
# 500              84                84             58           2.2
# ...

# %%
#15. Remove duplicate records from the dataset

df.drop_duplicates(inplace=True)

# %%
#16. Verify the dataset size after removing duplicates.

df.shape
# Out:
# (500, 18)

# %%
#17. Find the number of unique values in the city column.

df["city"].nunique()
# Out:
# 6

# %%
#18. Find the number of unique values in the course column

df["course"].nunique()
# Out:
# 4

# %%
#19. Display all unique cities present in the dataset.

df["city"].unique()
# Out:
# array(['Hyderabad', 'Pune', 'Delhi', 'Mumbai', 'Chennai', 'Bangalore'],
#       dtype=object)

# %%
#20. Count the number of students in each city

df["city"].value_counts()
# Out:
# city
# Hyderabad    99
# Mumbai       93
# Pune         87
# Bangalore    81
# Chennai      73
# Delhi        67
# Name: count, dtype: int64

# %%
#21. Count the number of students enrolled in each course.

df["course"].value_counts()
# Out:
# course
# Data Analytics    143
# Data Science      128
# AI & ML           125
# Generative AI     104
# Name: count, dtype: int64

# %%
#22. Identify the course with the highest student enrollment.

df['course'].value_counts().sort_values(ascending=False).head(1)
# Out:
# course
# Data Analytics    143
# Name: count, dtype: int64

# %%
#23. Count the number of students who are placed and not placed.

df["placement_status"].value_counts()
# Out:
# placement_status
# Placed        333
# Not Placed    167
# Name: count, dtype: int64

# %%
#24. Filter students whose attendance percentage is greater than 80

df[df["attendance_pct"] > 80]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 0          1001    Student_1    Male  Hyderabad      2024-11-25
# 1          1002    Student_2  Female  Hyderabad      2024-09-29
# 4          1005    Student_5    Male     Mumbai      2024-02-03
# 6          1007    Student_7    Male     Mumbai      2024-02-22
# 7          1008    Student_8    Male    Chennai      2024-07-23
# ..          ...          ...     ...        ...             ...
# 474        1475  Student_475    Male      Delhi      2024-04-21
# 475        1476  Student_476  Female    Chennai      2024-02-05
# 477        1478  Student_478  Female     Mumbai      2024-07-06
# 481        1482  Student_482  Female     Mumbai      2024-07-15
# 488        1489  Student_489    Male    Chennai      2024-10-19
#
#              course batch_type  total_sessions  sessions_attended  \
# 0     Generative AI    Weekday             120                108
# ...

# %%
#25. Filter students who attended fewer than 70 sessions.

df[df["sessions_attended"] < 70]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 34         1035   Student_35  Female  Hyderabad      2024-06-18
# 37         1038   Student_38    Male    Chennai      2024-11-21
# 39         1040   Student_40    Male  Bangalore      2024-05-12
# 43         1044   Student_44  Female     Mumbai      2024-02-15
# 48         1049   Student_49  Female    Chennai      2024-03-13
# ..          ...          ...     ...        ...             ...
# 485        1486  Student_486  Female     Mumbai      2024-04-28
# 487        1488  Student_488  Female       Pune      2024-09-17
# 490        1491  Student_491  Female  Bangalore      2024-08-09
# 494        1495  Student_495    Male       Pune      2024-12-07
# 496        1497  Student_497    Male  Hyderabad      2024-10-06
#
#              course batch_type  total_sessions  sessions_attended  \
# 34   Data Analytics    Weekday             120                 67
# ...

# %%
#26. Filter students with an average quiz score above 85

df[df["avg_quiz_score"] > 85]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 6          1007    Student_7    Male     Mumbai      2024-02-22
# 14         1015   Student_15  Female      Delhi      2024-05-30
# 16         1017   Student_17  Female     Mumbai      2024-12-01
# 23         1024   Student_24  Female  Hyderabad      2024-12-17
# 33         1034   Student_34  Female  Bangalore      2024-04-01
# ..          ...          ...     ...        ...             ...
# 487        1488  Student_488  Female       Pune      2024-09-17
# 491        1492  Student_492    Male    Chennai      2024-08-13
# 495        1496  Student_496    Male  Hyderabad      2024-12-29
# 496        1497  Student_497    Male  Hyderabad      2024-10-06
# 497        1498  Student_498  Female  Bangalore      2024-03-21
#
#              course batch_type  total_sessions  sessions_attended  \
# 6    Data Analytics    Weekend             120                112
# ...

# %%
#27. Filter students enrolled in the Data Science course.

df[df["course"] == "Data Science"]
# Out:
#      student_id student_name  gender       city enrollment_date        course  \
# 2          1003    Student_3    Male       Pune      2024-12-05  Data Science
# 7          1008    Student_8    Male    Chennai      2024-07-23  Data Science
# 10         1011   Student_11    Male    Chennai      2024-02-12  Data Science
# 13         1014   Student_14    Male     Mumbai      2024-09-05  Data Science
# 18         1019   Student_19  Female       Pune      2024-01-08  Data Science
# ..          ...          ...     ...        ...             ...           ...
# 487        1488  Student_488  Female       Pune      2024-09-17  Data Science
# 489        1490  Student_490    Male       Pune      2024-09-12  Data Science
# 490        1491  Student_491  Female  Bangalore      2024-08-09  Data Science
# 495        1496  Student_496    Male  Hyderabad      2024-12-29  Data Science
# 498        1499  Student_499    Male     Mumbai      2024-07-20  Data Science
#
# ...

# %%
#28. Filter students who are not placed and attended more than 75 sessions

df[(df["placement_status"] == "Not Placed") & (df["sessions_attended"] > 75)]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 1          1002    Student_2  Female  Hyderabad      2024-09-29
# 9          1010   Student_10  Female      Delhi      2024-08-22
# 10         1011   Student_11    Male    Chennai      2024-02-12
# 15         1016   Student_16    Male     Mumbai      2024-07-01
# 16         1017   Student_17  Female     Mumbai      2024-12-01
# ..          ...          ...     ...        ...             ...
# 464        1465  Student_465  Female    Chennai      2024-06-30
# 469        1470  Student_470  Female  Hyderabad      2024-09-19
# 473        1474  Student_474  Female      Delhi      2024-05-26
# 480        1481  Student_481  Female     Mumbai      2024-10-29
# 488        1489  Student_489    Male    Chennai      2024-10-19
#
#              course batch_type  total_sessions  sessions_attended  \
# 1           AI & ML    Weekday             120                110
# ...

# %%
#29. Filter students belonging to Pune, Bangalore, or Hyderabad

df[df["city"].isin(["Pune","Bangalore","Hyderabad"])]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 0          1001    Student_1    Male  Hyderabad      2024-11-25
# 1          1002    Student_2  Female  Hyderabad      2024-09-29
# 2          1003    Student_3    Male       Pune      2024-12-05
# 5          1006    Student_6  Female       Pune      2024-09-18
# 18         1019   Student_19  Female       Pune      2024-01-08
# ..          ...          ...     ...        ...             ...
# 494        1495  Student_495    Male       Pune      2024-12-07
# 495        1496  Student_496    Male  Hyderabad      2024-12-29
# 496        1497  Student_497    Male  Hyderabad      2024-10-06
# 497        1498  Student_498  Female  Bangalore      2024-03-21
# 499        1500  Student_500  Female       Pune      2024-06-06
#
#              course batch_type  total_sessions  sessions_attended  \
# 0     Generative AI    Weekday             120                108
# ...

# %%
#30. Filter students enrolled in AI & ML or Generative AI courses

df[df["course"].isin(["AI & ML","Generative AI"])]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 0          1001    Student_1    Male  Hyderabad      2024-11-25
# 1          1002    Student_2  Female  Hyderabad      2024-09-29
# 3          1004    Student_4    Male      Delhi      2024-03-09
# 4          1005    Student_5    Male     Mumbai      2024-02-03
# 5          1006    Student_6  Female       Pune      2024-09-18
# ..          ...          ...     ...        ...             ...
# 488        1489  Student_489    Male    Chennai      2024-10-19
# 493        1494  Student_494  Female      Delhi      2024-12-20
# 494        1495  Student_495    Male       Pune      2024-12-07
# 496        1497  Student_497    Male  Hyderabad      2024-10-06
# 499        1500  Student_500  Female       Pune      2024-06-06
#
#             course batch_type  total_sessions  sessions_attended  \
# 0    Generative AI    Weekday             120                108
# ...

# %%
#31. Filter students whose average quiz score lies between 60 and 80

df[df["avg_quiz_score"].between(60,80)]
# Out:
#      student_id student_name  gender     city enrollment_date          course  \
# 3          1004    Student_4    Male    Delhi      2024-03-09         AI & ML
# 5          1006    Student_6  Female     Pune      2024-09-18   Generative AI
# 7          1008    Student_8    Male  Chennai      2024-07-23    Data Science
# 8          1009    Student_9    Male   Mumbai      2024-05-05         AI & ML
# 9          1010   Student_10  Female    Delhi      2024-08-22  Data Analytics
# ..          ...          ...     ...      ...             ...             ...
# 488        1489  Student_489    Male  Chennai      2024-10-19   Generative AI
# 489        1490  Student_490    Male     Pune      2024-09-12    Data Science
# 493        1494  Student_494  Female    Delhi      2024-12-20   Generative AI
# 494        1495  Student_495    Male     Pune      2024-12-07         AI & ML
# 498        1499  Student_499    Male   Mumbai      2024-07-20    Data Science
#
# ...

# %%
#32. Filter students whose assignment score lies between 70 and 90.

df[df["assignment_score"].between(70,90)]
# Out:
#      student_id student_name  gender     city enrollment_date          course  \
# 2          1003    Student_3    Male     Pune      2024-12-05    Data Science
# 6          1007    Student_7    Male   Mumbai      2024-02-22  Data Analytics
# 7          1008    Student_8    Male  Chennai      2024-07-23    Data Science
# 14         1015   Student_15  Female    Delhi      2024-05-30  Data Analytics
# 20         1021   Student_21  Female     Pune      2024-07-02         AI & ML
# ..          ...          ...     ...      ...             ...             ...
# 484        1485  Student_485    Male    Delhi      2024-07-13    Data Science
# 491        1492  Student_492    Male  Chennai      2024-08-13  Data Analytics
# 493        1494  Student_494  Female    Delhi      2024-12-20   Generative AI
# 494        1495  Student_495    Male     Pune      2024-12-07         AI & ML
# 499        1500  Student_500  Female     Pune      2024-06-06         AI & ML
#
# ...

# %%
#33. Filter students whose learning hours lie between 10 and 25

df[df["learning_hours"].between(10,25)]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 4          1005    Student_5    Male     Mumbai      2024-02-03
# 7          1008    Student_8    Male    Chennai      2024-07-23
# 8          1009    Student_9    Male     Mumbai      2024-05-05
# 10         1011   Student_11    Male    Chennai      2024-02-12
# 18         1019   Student_19  Female       Pune      2024-01-08
# ..          ...          ...     ...        ...             ...
# 479        1480  Student_480  Female     Mumbai      2024-01-02
# 485        1486  Student_486  Female     Mumbai      2024-04-28
# 491        1492  Student_492    Male    Chennai      2024-08-13
# 495        1496  Student_496    Male  Hyderabad      2024-12-29
# 499        1500  Student_500  Female       Pune      2024-06-06
#
#              course batch_type  total_sessions  sessions_attended  \
# 4     Generative AI    Weekday             120                101
# ...

# %%
#34. Create a new column total_score as the sum of quiz, assignment, and project scores

df["total_score"] = df["avg_quiz_score"] + df["assignment_score"] + df["project_score"]

# %%
df.head()
# Out:
#    student_id student_name  gender       city enrollment_date         course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05   Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  \
# 0    Weekday             120                108              59
# 1    Weekday             120                110              57
# 2    Weekday             120                 73              49
# 3    Weekend             120                 71              64
# 4    Weekday             120                101              41
#
#    assignment_score  project_score  final_rating  learning_hours  \
# ...

# %%
#35. Create a new column attendance_flag based on attendance percentage

def attendance_label(x):
    if x >= 75:
        return "Good"
    else:
        return "Poor"

df["attendance_flag"] = df["attendance_pct"].apply(attendance_label)

# %%
df.head()
# Out:
#    student_id student_name  gender       city enrollment_date         course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05   Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  \
# 0    Weekday             120                108              59
# 1    Weekday             120                110              57
# 2    Weekday             120                 73              49
# 3    Weekend             120                 71              64
# 4    Weekday             120                101              41
#
#    assignment_score  project_score  final_rating  learning_hours  \
# ...

# %%
#36. Create a new column learning_intensity based on learning hours.

def learning_hrs(x):
    if x > 20:
        return "High"
    elif x >= 10:
        return "Medium"
    else:
        return "Low"

df["learning_intensity"] = df["learning_hours"].apply(learning_hrs)

# %%
df.head()
# Out:
#    student_id student_name  gender       city enrollment_date         course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05   Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  ...  \
# 0    Weekday             120                108              59  ...
# 1    Weekday             120                110              57  ...
# 2    Weekday             120                 73              49  ...
# 3    Weekend             120                 71              64  ...
# 4    Weekday             120                101              41  ...
#
#    project_score  final_rating  learning_hours  placement_status  \
# ...

# %%
#37. Classify students based on total_score using apply().

def student_performance(x):
    if x >= 250:
        return "Excellent"
    elif x >= 200:
        return "Good"
    else:
        return "Poor"

df["performance"] = df["total_score"].apply(student_performance)

# %%
df.head()
# Out:
#    student_id student_name  gender       city enrollment_date         course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05   Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  ...  \
# 0    Weekday             120                108              59  ...
# 1    Weekday             120                110              57  ...
# 2    Weekday             120                 73              49  ...
# 3    Weekend             120                 71              64  ...
# 4    Weekday             120                101              41  ...
#
#    final_rating  learning_hours  placement_status  feedback_score  \
# ...

# %%
#38. Create a placement eligibility column using apply().

def eligible(x):
    if x["attendance_pct"] >= 75 and x["total_score"] >= 200:
        return "Eligible"
    else:
        return "Not Eligible"

df["placement_eligibilty"] = df.apply(eligible, axis=1)

# %%
df.head()
# Out:
#    student_id student_name  gender       city enrollment_date         course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05   Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  ...  \
# 0    Weekday             120                108              59  ...
# 1    Weekday             120                110              57  ...
# 2    Weekday             120                 73              49  ...
# 3    Weekend             120                 71              64  ...
# 4    Weekday             120                101              41  ...
#
#    learning_hours  placement_status  feedback_score  attendance_pct  \
# ...

# %%
#39. Map placement_status values to numerical values.

placement = {"Placed" : 1, "Not Placed" : 0}

df["placement_numeric_status"] = df["placement_status"].map(placement)

# %%
df.head()
# Out:
#    student_id student_name  gender       city enrollment_date         course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05   Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  ...  \
# 0    Weekday             120                108              59  ...
# 1    Weekday             120                110              57  ...
# 2    Weekday             120                 73              49  ...
# 3    Weekend             120                 71              64  ...
# 4    Weekday             120                101              41  ...
#
#    placement_status  feedback_score  attendance_pct  salary_offered  \
# ...

# %%
#40. Map batch_type values to abbreviated codes.

code = {"weekend" : "WE", "weekday" : "WD"}

df["batch_code"] = df["batch_type"].map(code)

# %%
df.head()
# Out:
#    student_id student_name  gender       city enrollment_date         course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05   Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  ...  \
# 0    Weekday             120                108              59  ...
# 1    Weekday             120                110              57  ...
# 2    Weekday             120                 73              49  ...
# 3    Weekend             120                 71              64  ...
# 4    Weekday             120                101              41  ...
#
#    feedback_score  attendance_pct  salary_offered  total_score  \
# ...

# %%
#41. Map gender values to single-letter codes.

gender = {"Male" : "M", "Female":"F"}

df["gender_code"] = df["gender"].map(gender)

# %%
df.head()
# Out:
#    student_id student_name  gender       city enrollment_date         course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05   Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  ...  \
# 0    Weekday             120                108              59  ...
# 1    Weekday             120                110              57  ...
# 2    Weekday             120                 73              49  ...
# 3    Weekend             120                 71              64  ...
# 4    Weekday             120                101              41  ...
#
#    attendance_pct  salary_offered  total_score  attendance_flag  \
# ...

# %%
#42. Count students under each learning_intensity category.

df["learning_intensity"].value_counts()
# Out:
# learning_intensity
# High      279
# Medium    149
# Low        72
# Name: count, dtype: int64

# %%
#43. Calculate the percentage of placement-eligible students.

print(df['placement_eligibilty'].value_counts()[1]/len(df) * 100)
# Out:
# 34.2
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14552\1097179187.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(df['placement_eligibilty'].value_counts()[1]/len(df) * 100)

# %%
#44. Identify the city with the highest number of placed students.

df['city'].value_counts().sort_values(ascending=False).head(1)
# Out:
# city
# Hyderabad    99
# Name: count, dtype: int64

# %%
#45. Compare average total_score for placed and not placed students

df.groupby('placement_status')['total_score'].mean()
# Out:
# placement_status
# Not Placed    214.952096
# Placed        217.606607
# Name: total_score, dtype: float64

# %%
#46. Identify the top 5 students based on total_score.

df.sort_values(["total_score"], ascending = False).head()
# Out:
#      student_id student_name  gender     city enrollment_date          course  \
# 475        1476  Student_476  Female  Chennai      2024-02-05  Data Analytics
# 178        1179  Student_179    Male   Mumbai      2024-04-22         AI & ML
# 183        1184  Student_184    Male   Mumbai      2024-05-21    Data Science
# 144        1145  Student_145  Female   Mumbai      2024-05-31    Data Science
# 263        1264  Student_264    Male    Delhi      2024-05-13   Generative AI
#
#     batch_type  total_sessions  sessions_attended  avg_quiz_score  ...  \
# 475    Weekday             120                 97              99  ...
# 178    Weekday             120                 82              99  ...
# 183    Weekend             120                112              94  ...
# 144    Weekend             120                105              92  ...
# 263    Weekday             120                101              97  ...
#
#      attendance_pct  salary_offered  total_score  attendance_flag  \
# ...

# %%
#1. Group the data by course and calculate the average attendance percentage

df.groupby("course")["attendance_pct"].mean()
# Out:
# course
# AI & ML           73.066960
# Data Analytics    73.146713
# Data Science      73.632578
# Generative AI     74.126635
# Name: attendance_pct, dtype: float64

# %%
#2. Group the data by city and count the number of students in each city.

df.groupby("city")["student_id"].count()
# Out:
# city
# Bangalore    81
# Chennai      73
# Delhi        67
# Hyderabad    99
# Mumbai       93
# Pune         87
# Name: student_id, dtype: int64

# %%
#3. Group the data by batch_type and calculate the average quiz score.

df.groupby("batch_type")["avg_quiz_score"].mean()
# Out:
# batch_type
# Weekday    69.483193
# Weekend    69.591603
# Name: avg_quiz_score, dtype: float64

# %%
#4. Group the data by placement_status and calculate the average total_score.

df.groupby("placement_status")["total_score"].mean()
# Out:
# placement_status
# Not Placed    214.952096
# Placed        217.606607
# Name: total_score, dtype: float64

# %%
#5. Group the data by course and city and calculate the number of students in each combination.

df.groupby(["course","city"])["student_id"].count()
# Out:
# course          city
# AI & ML         Bangalore    20
#                 Chennai      14
#                 Delhi        16
#                 Hyderabad    19
#                 Mumbai       30
#                 Pune         26
# Data Analytics  Bangalore    25
#                 Chennai      18
#                 Delhi        21
#                 Hyderabad    33
#                 Mumbai       26
#                 Pune         20
# Data Science    Bangalore    19
#                 Chennai      24
#                 Delhi        12
#                 Hyderabad    31
#                 Mumbai       20
#                 Pune         22
# Generative AI   Bangalore    17
#                 Chennai      17
#                 Delhi        18
#                 Hyderabad    16
#                 Mumbai       17
#                 Pune         19
# Name: student_id, dtype: int64

# %%
#6. Group the data by course and calculate the maximum, minimum, and average project score.

df.groupby("course")["project_score"].agg(["max","min","mean"])
# Out:
#                 max  min       mean
# course
# AI & ML          99   50  74.136000
# Data Analytics   99   50  75.839161
# Data Science     99   50  75.992188
# Generative AI    98   50  75.221154

# %%
#7. Group the data by city and calculate total and average learning hours.

df.groupby("city")["learning_hours"].agg(["sum","mean"])
# Out:
#             sum       mean
# city
# Bangalore  1851  22.851852
# Chennai    1557  21.328767
# Delhi      1473  21.985075
# Hyderabad  2190  22.121212
# Mumbai     2106  22.645161
# Pune       1886  21.678161

# %%
#8. Group the data by course and placement_status and count students.

df.groupby("course")["placement_status"].count()
# Out:
# course
# AI & ML           125
# Data Analytics    143
# Data Science      128
# Generative AI     104
# Name: placement_status, dtype: int64

# %%
#9. Filter grouped results to display only courses with average attendance percentage greater than 80.

avg_attendance_pct = df.groupby("course")["attendance_pct"].mean()

# %%
avg_attendance_pct[avg_attendance_pct > 80]
# Out:
# Series([], Name: attendance_pct, dtype: float64)

# %%
#10. Filter grouped results to show only cities with more than 50 students.

count_students = df.groupby("city")["student_id"].count()

# %%
count_students[count_students > 50]
# Out:
# city
# Bangalore    81
# Chennai      73
# Delhi        67
# Hyderabad    99
# Mumbai       93
# Pune         87
# Name: student_id, dtype: int64

# %%
#11. Perform multiple aggregations on course to calculate average quiz score, average assignment score, and average project score.

df.groupby("course")[["avg_quiz_score","assignment_score","project_score"]].mean()
# Out:
#                 avg_quiz_score  assignment_score  project_score
# course
# AI & ML              69.256000         71.544000      74.136000
# Data Analytics       69.041958         71.545455      75.839161
# Data Science         69.960938         72.656250      75.992188
# Generative AI        70.048077         71.673077      75.221154

# %%
#12. Perform named aggregations on course to calculate average_attendance, max_project_score, and mean_total_score

df.groupby("course").agg(AverageAttendance=("attendance_pct","mean"),
                         MaxProjectScore=("project_score","max"),
                         MeanTotalScore=("total_score","mean"))
# Out:
#                 AverageAttendance  MaxProjectScore  MeanTotalScore
# course
# AI & ML                 73.066960               99      214.936000
# Data Analytics          73.146713               99      216.426573
# Data Science            73.632578               99      218.609375
# Generative AI           74.126635               98      216.942308

# %%
#13. Perform named aggregations on city to calculate total_students, placed_students, and average_salary

df.groupby("city").agg(TotalStudents=("student_id","count"),
                       PlacedStudents=("placement_numeric_status","sum"),
                       AverageSalary=("salary_offered","mean"))
# Out:
#            TotalStudents  PlacedStudents  AverageSalary
# city
# Bangalore             81              61  806146.393443
# Chennai               73              44  823148.090909
# Delhi                 67              36  756018.277778
# Hyderabad             99              69  703994.405797
# Mumbai                93              63  764211.809524
# Pune                  87              60  779828.883333

# %%
df["enrollment_date"] = pd.to_datetime(df["enrollment_date"])

# %%
#14. Extract year from enrollment_date and add it as a new column.

df["Enrollment_year"]=df["enrollment_date"].dt.year
df.head()
# Out:
#    student_id student_name  gender       city enrollment_date         course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05   Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  ...  \
# 0    Weekday             120                108              59  ...
# 1    Weekday             120                110              57  ...
# 2    Weekday             120                 73              49  ...
# 3    Weekend             120                 71              64  ...
# 4    Weekday             120                101              41  ...
#
#    salary_offered  total_score  attendance_flag  learning_intensity  \
# ...

# %%
#15. Extract month number from enrollment_date and add it as a new column.

df["Enrollment_month"] = df["enrollment_date"].dt.month
df.head()
# Out:
#    student_id student_name  gender       city enrollment_date         course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05   Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  ...  \
# 0    Weekday             120                108              59  ...
# 1    Weekday             120                110              57  ...
# 2    Weekday             120                 73              49  ...
# 3    Weekend             120                 71              64  ...
# 4    Weekday             120                101              41  ...
#
#    total_score  attendance_flag  learning_intensity  performance  \
# ...

# %%
#16. Extract month name from enrollment_date and add it as a new column.

df["MonthName"] = df["enrollment_date"].dt.month_name()
df.head()
# Out:
#    student_id student_name  gender       city enrollment_date         course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05   Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  ...  \
# 0    Weekday             120                108              59  ...
# 1    Weekday             120                110              57  ...
# 2    Weekday             120                 73              49  ...
# 3    Weekend             120                 71              64  ...
# 4    Weekday             120                101              41  ...
#
#    attendance_flag  learning_intensity  performance  placement_eligibilty  \
# ...

# %%
#17. Extract day name from enrollment_date and add it as a new column.

df["DayName"] = df["enrollment_date"].dt.day_name()
df.head()
# Out:
#    student_id student_name  gender       city enrollment_date         course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05   Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  ...  \
# 0    Weekday             120                108              59  ...
# 1    Weekday             120                110              57  ...
# 2    Weekday             120                 73              49  ...
# 3    Weekend             120                 71              64  ...
# 4    Weekday             120                101              41  ...
#
#    learning_intensity  performance  placement_eligibilty  \
# ...

# %%
#18. Extract quarter from enrollment_date and add it as a new column.

df["Quarter"] = df["enrollment_date"].dt.quarter
df.head()
# Out:
#    student_id student_name  gender       city enrollment_date         course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05   Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  ...  \
# 0    Weekday             120                108              59  ...
# 1    Weekday             120                110              57  ...
# 2    Weekday             120                 73              49  ...
# 3    Weekend             120                 71              64  ...
# 4    Weekday             120                101              41  ...
#
#    performance  placement_eligibilty  placement_numeric_status  batch_code  \
# ...

# %%
#19. Group the data by year and calculate the number of student enrollments.

df.groupby("Enrollment_year")["student_id"].count()
# Out:
# Enrollment_year
# 2024    500
# Name: student_id, dtype: int64

# %%
#20. Group the data by month name and calculate average attendance percentage.

df.groupby("MonthName")["attendance_pct"].mean()
# Out:
# MonthName
# April        71.406250
# August       69.603333
# December     73.603243
# February     71.824054
# January      72.907959
# July         76.972667
# June         72.479268
# March        72.970000
# May          74.072500
# November     73.775714
# October      78.529412
# September    73.257273
# Name: attendance_pct, dtype: float64

# %%
#21. Group the data by quarter and calculate average total_score.

df.groupby("Quarter")["total_score"].mean()
# Out:
# Quarter
# 1    214.296000
# 2    218.082707
# 3    217.533333
# 4    216.985401
# Name: total_score, dtype: float64

# %%
#22. Group the data by day name and count the number of enrollments.

df.groupby("DayName")["student_id"].count()
# Out:
# DayName
# Friday       74
# Monday       78
# Saturday     85
# Sunday       74
# Thursday     76
# Tuesday      60
# Wednesday    53
# Name: student_id, dtype: int64

# %%
#23. Identify the month with the highest number of enrollments.

df.groupby("MonthName")["student_id"].count().sort_values(ascending=False).head(1)
# Out:
# MonthName
# October    51
# Name: student_id, dtype: int64

# %%
#24. Identify the quarter with the highest average project score.

df.groupby("Quarter")["project_score"].mean().sort_values(ascending=False).head(1)
# Out:
# Quarter
# 2    76.045113
# Name: project_score, dtype: float64

# %%
#25. Group the data by year and course and calculate average quiz score.

df.groupby(["Enrollment_year","course"])["avg_quiz_score"].mean()
# Out:
# Enrollment_year  course
# 2024             AI & ML           69.256000
#                  Data Analytics    69.041958
#                  Data Science      69.960938
#                  Generative AI     70.048077
# Name: avg_quiz_score, dtype: float64

# %%
#26. Group the data by month name and placement_status and count students.

df.groupby(["MonthName","placement_status"])["student_id"].count()
# Out:
# MonthName  placement_status
# April      Not Placed          15
#            Placed              33
# August     Not Placed          16
#            Placed              26
# December   Not Placed          16
#            Placed              21
# February   Not Placed          10
#            Placed              27
# January    Not Placed          19
#            Placed              30
# July       Not Placed          10
#            Placed              20
# June       Not Placed          14
#            Placed              27
# March      Not Placed          12
#            Placed              27
# May        Not Placed          13
#            Placed              31
# November   Not Placed          18
#            Placed              31
# October    Not Placed          16
#            Placed              35
# September  Not Placed           8
#            Placed              25
# Name: student_id, dtype: int64

# %%
#27. Group the data by city and year and calculate placement count.

df[df["placement_numeric_status"] == 1].groupby(["city", "Enrollment_year"])["student_id"].count()
# Out:
# city       Enrollment_year
# Bangalore  2024               61
# Chennai    2024               44
# Delhi      2024               36
# Hyderabad  2024               69
# Mumbai     2024               63
# Pune       2024               60
# Name: student_id, dtype: int64

# %%
#28. Filter grouped year-wise enrollments to display only years with more than 100 enrollments.

year_wise_enrollments = df.groupby("Enrollment_year")["student_id"].count()

# %%
year_wise_enrollments[year_wise_enrollments > 100]
# Out:
# Enrollment_year
# 2024    500
# Name: student_id, dtype: int64

# %%
#29. Filter grouped course-wise performance to show only courses with average total_score above 220.

course_avg_score = df.groupby("course")["total_score"].mean()

# %%
course_avg_score[course_avg_score > 220]
# Out:
# Series([], Name: total_score, dtype: float64)

# %%
#30. Compare average attendance percentage across quarters.

df.groupby("Quarter")["attendance_pct"].mean()
# Out:
# Quarter
# 1    72.606480
# 2    72.619098
# 3    72.857238
# 4    75.498759
# Name: attendance_pct, dtype: float64

# %%
#31. Calculate average salary offered per course using groupby.

df.groupby("course")["salary_offered"].mean()
# Out:
# course
# AI & ML           785944.506494
# Data Analytics    788028.545455
# Data Science      781899.318182
# Generative AI     706972.492754
# Name: salary_offered, dtype: float64

# %%
#32. Calculate average salary offered per city using groupby.

df.groupby("city")["salary_offered"].mean()
# Out:
# city
# Bangalore    806146.393443
# Chennai      823148.090909
# Delhi        756018.277778
# Hyderabad    703994.405797
# Mumbai       764211.809524
# Pune         779828.883333
# Name: salary_offered, dtype: float64

# %%
#33. Identify top 3 cities based on average salary offered.

df.groupby("city")["salary_offered"].mean().sort_values(ascending=False).head(3)
# Out:
# city
# Chennai      823148.090909
# Bangalore    806146.393443
# Pune         779828.883333
# Name: salary_offered, dtype: float64

# %%
#34. Identify the course with the highest placement rate using groupby analysis.

df.groupby("course")["placement_numeric_status"].mean().sort_values(ascending=False).head(1)
# Out:
# course
# Data Analytics    0.692308
# Name: placement_numeric_status, dtype: float64

# %%
#35. Group the data by batch_type and quarter to analyze attendance patterns.

df.groupby(["batch_type", "Quarter"])["attendance_pct"].mean()
# Out:
# batch_type  Quarter
# Weekday     1          71.958772
#             2          71.835652
#             3          74.947917
#             4          73.671719
# Weekend     1          73.149412
#             2          73.463750
#             3          71.096667
#             4          77.100548
# Name: attendance_pct, dtype: float64

# %%
#36. Group the data by month name and course to analyze enrollment distribution.

df.groupby(["MonthName", "course"])["student_id"].count()
# Out:
# MonthName  course
# April      AI & ML            6
#            Data Analytics    17
#            Data Science      13
#            Generative AI     12
# August     AI & ML           12
#            Data Analytics    15
#            Data Science       6
#            Generative AI      9
# December   AI & ML            9
#            Data Analytics    11
#            Data Science      11
#            Generative AI      6
# February   AI & ML           10
#            Data Analytics    10
#            Data Science      11
#            Generative AI      6
# January    AI & ML           14
#            Data Analytics    15
#            Data Science      11
#            Generative AI      9
# July       AI & ML           10
#            Data Analytics     5
#            Data Science       8
#            Generative AI      7
# June       AI & ML            8
#            Data Analytics    13
#            Data Science      13
#            Generative AI      7
# ...

# %%
#37. Identify days of the week with maximum enrollments.

df.groupby("DayName")["student_id"].count().sort_values(ascending=False).head(1)
# Out:
# DayName
# Saturday    85
# Name: student_id, dtype: int64

# %%
#38. Analyze placement status distribution across quarters.

df.groupby(["Quarter", "placement_numeric_status"])["student_id"].count()
# Out:
# Quarter  placement_numeric_status
# 1        0                           41
#          1                           84
# 2        0                           42
#          1                           91
# 3        0                           34
#          1                           71
# 4        0                           50
#          1                           87
# Name: student_id, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.dtypes
# Out:
# student_id                           int64
# student_name                        object
# gender                              object
# city                                object
# enrollment_date             datetime64[ns]
# course                              object
# batch_type                          object
# total_sessions                       int64
# sessions_attended                    int64
# avg_quiz_score                       int64
# assignment_score                     int64
# project_score                        int64
# final_rating                       float64
# learning_hours                       int64
# placement_status                    object
# feedback_score                       int64
# attendance_pct                     float64
# salary_offered                     float64
# total_score                          int64
# attendance_flag                     object
# learning_intensity                  object
# performance                         object
# ...

# %%
plt.hist(df["total_sessions"],edgecolor="black")
plt.title("Distribution of total_sessions using Histogram")
plt.xlabel("total_sessions")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# - The distribution shows that there are total 120 sessions

# %%
plt.hist(df["sessions_attended"],edgecolor="black")
plt.title("Distribution of sessions_attended using Histogram")
plt.xlabel("sessions_attended")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# - The distribution shows that many students have attended 60 to 80 sessions.
# - Few students have attended above 110 sessions

# %%
plt.hist(df["avg_quiz_score"],edgecolor="black")
plt.title("Distribution of avg_quiz_score using Histogram")
plt.xlabel("avg_quiz_score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# - The distribution shows that many students average quiz score is 60.
# - Few students have average quiz score between 80 to 90

# %%
plt.hist(df["assignment_score"],edgecolor="black")
plt.title("Distribution of assignment_score using Histogram")
plt.xlabel("assignment_score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# - The distribution shows that many students have assignment score 50.
# - Few students have 55 assignment score

# %%
plt.hist(df["project_score"],edgecolor="black")
plt.title("Distribution of project_score using Histogram")
plt.xlabel("project_score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# - The distribution shows that many students project score is between 85 to 90
# - Few students have project score between 55 to 60

# %%
plt.hist(df["final_rating"],edgecolor="black")
plt.title("Distribution of final_rating using Histogram")
plt.xlabel("final_rating")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# - The distribution shows that many students have 3.5 to 3.7 final rating
# - Few students have 2 and 3 final rating

# %%
plt.hist(df["learning_hours"],edgecolor="black")
plt.title("Distribution of learning_hours using Histogram")
plt.xlabel("learning_hours")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# - The distribution shows that learning hours of many students are 5 and 15 hours.
# - Few students have 10 and 15 to 18 hours of learning

# %%
plt.hist(df["feedback_score"],edgecolor="black")
plt.title("Distribution of feedback_score using Histogram")
plt.xlabel("feedback_score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# - The distribution shows that highest feedback score of many students is 8.
# - Few students have feedback score of 5

# %%
plt.hist(df["attendance_pct"],edgecolor="black")
plt.title("Distribution of attendance_pct using Histogram")
plt.xlabel("attendance_pct")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# - The distribution shows that attendance percent of many students is between 50 to 55.
# - Few students have attendance percent above 95.

# %%
plt.hist(df["salary_offered"],edgecolor="black")
plt.title("Distribution of salary_offered using Histogram")
plt.xlabel("salary_offered")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# - The distribution shows that highest salary offered is around 12 lakhs.
# - Lowest salary offered is around 60000

# %%
plt.hist(df["total_score"],edgecolor="black")
plt.title("Distribution of total_score using Histogram")
plt.xlabel("total_score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# - The distribution shows that many students have total between 220 and 230.
# - Few students have total score near 140 and near 280

# %%
plt.hist(df["placement_numeric_status"],edgecolor="black")
plt.title("Distribution of placement_numeric_status using Histogram")
plt.xlabel("placement_numeric_status")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# - The distribution shows that around 350 students has placed and around 160 students has not placed

# %%
sns.countplot(x=df["gender"],data=df)
plt.title("Countplot for gender")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The distribution shows that count of female students are higher than count of male students

# %%
sns.countplot(x=df["city"],data=df)
plt.title("Countplot for city")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The distribution shows that Hyderabad has highest count of students.
# - Delhi has lowest count of students

# %%
sns.countplot(x=df["course"],data=df)
plt.title("Countplot for course")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The distribution shows that Data Analytics course has highest count of students.
# - Generative AI has lowest count of students.
# - AI & ML and Data Science has the almost similar students.

# %%
sns.countplot(x=df["batch_type"],data=df)
plt.title("Countplot for batch_type")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The distribution shows that many students do sessions on weekends.
# - Count of students for sessions on weekdays are less

# %%
sns.countplot(x=df["placement_status"],data=df)
plt.title("Countplot for placement_status")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The distribution shows that count of placed students are highest than count of Not Placed students

# %%
sns.countplot(x=df["attendance_flag"],data=df)
plt.title("Countplot for attendance_flag")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The distribution shows that many students have less attendance for sessions around 260 to 270.
# - Around 240 students have good attendance.

# %%
sns.countplot(x=df["learning_intensity"],data=df)
plt.title("Countplot for learning_intensity")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The distribution shows that count of high learning intensity of students are highest and low learning intensity are

# %%
sns.countplot(x=df["performance"],data=df)
plt.title("Countplot for performance")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The distribution shows that count of Good performance students are highest and count of Excellent performance are lowest

# %%
sns.countplot(x=df["placement_eligibilty"],data=df)
plt.title("Countplot for placement_eligibilty")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The distribution shows that count of Not Eligible students are highest than count of Eligible students

# %%
sns.countplot(x=df["city"], hue="course", data=df)
plt.title("city wise course count")
plt.xlabel("city")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The visualization shows that In Hyderabad highest count is for Data Analytics and Data Science has less count followed by data analytics, and it have very less count for Generative AI course.
# - In Pune highest count is for AI & ML course and less count is for Generative AI.
# - In Delhi highest count is for Data Analytics and low count is for Data Science.
# - In Mumbai highest count is for AI & ML and low count is for Generative AI.
# - In Chennai highest count is for Data Science and low count is for AI & ML.
# - In Bangalore highest count is for Data Analytics and less count is for Generative AI.

# %%
sns.countplot(x=df["course"], hue="final_rating", data=df)
plt.title("course wise final_rating count")
plt.xlabel("course")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The visualiztion shows that Generative AI have highest count of rating in 3.0,3.5,5.0.
# - AI & ML have highest count of rating in 3.5 and 4.5.
# - Data Science have highes count of rating 4.5.
# - Data Analytics have highest count of rating 4.0.

# %%
sns.countplot(x=df["city"], hue="placement_status", data=df)
plt.title("city wise placement_status count")
plt.xlabel("city")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The visualization shows that Hyderabad has the highest count of placed students and Delhi has less count of placed students

# %%
sns.countplot(x=df["course"], hue="placement_status", data=df)
plt.title("course wise placement_status count")
plt.xlabel("course")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The visualization shows that highest count of placed students is in Data Analytics course and Less count of placed student is in Generative AI course, it means Data Analytics have High demand than Generative AI

# %%
sns.countplot(x=df["gender"], hue="performance", data=df)
plt.title("gender wise performance count")
plt.xlabel("gender")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The visualization shows that Female students count for good performance is highest than Male students.
# Highest count of students has Good performance and Few students have Excellent performance

# %%
plt.scatter(df["avg_quiz_score"],df["total_score"])
plt.xlabel("avg_quiz_score")
plt.ylabel("total_score")
plt.title("avg_quiz_score wise total_score")
plt.show()

# %% [markdown]
# The visualization shows that relationship between avg_quiz_score and total score is Positive as the quiz score increases total score also increases.

# %%
plt.scatter(df["assignment_score"],df["total_score"])
plt.xlabel("assignment_score")
plt.ylabel("total_score")
plt.title("assignment_score wise total_score")
plt.show()

# %% [markdown]
# The visualization shows that relationship between assignment score and total score is Positive as the assignment score increases total score also increases.

# %%
plt.scatter(df["project_score"],df["total_score"])
plt.xlabel("project_score")
plt.ylabel("total_score")
plt.title("project_score wise total_score")
plt.show()

# %% [markdown]
# The visualization shows that relationship between project score and total score is Positive as the project score increases total score also increases.

# %%
sns.regplot(x="sessions_attended",y="final_rating",data=df)
plt.title("Distribution of sessions_attended compared to final_rating")
plt.xlabel("sessions_attended")
plt.ylabel("final_rating")
plt.show()

# %% [markdown]
# The visualization indicates the upward trend in sessions attended and final rating, which means that there's a positive relationship as the sessions attended increases final rating also increases.

# %%
sns.regplot(x="sessions_attended",y="attendance_pct",data=df)
plt.title("Distribution of sessions_attended compared to attendance_pct")
plt.xlabel("sessions_attended")
plt.ylabel("attendance_pct")
plt.show()

# %% [markdown]
# The visualization indicates the upward trend in sessions attended and attendance percentage, which means that there's a positive relationship as the sessions attended increases attendance percentage also increases.

# %%
sns.regplot(x="avg_quiz_score",y="total_score",data=df)
plt.title("Distribution of avg_quiz_score compared to total_score")
plt.xlabel("avg_quiz_score")
plt.ylabel("total_score")
plt.show()

# %% [markdown]
# The visualization indicates indicates upward trend in average quiz score and total score, which means that there's a positive relationship as the quiz score increases total score also increases

# %%
sns.regplot(x="avg_quiz_score",y="salary_offered",data=df)
plt.title("Distribution of avg_quiz_score compared to salary_offered")
plt.xlabel("avg_quiz_score")
plt.ylabel("salary_offered")
plt.show()

# %% [markdown]
# The visualization indicates downward trend in quiz score and salary offered, which means that there's a negative relationship as the quiz score increases salary offered decreases

# %%
sns.regplot(x="assignment_score",y="learning_hours",data=df)
plt.title("Distribution of assignment_score compared to learning_hours")
plt.xlabel("assignment_score")
plt.ylabel("learning_hours")
plt.show()

# %% [markdown]
# The visualization indicates upward trend in assignment score and learning hours, which means that there's a positive relationship as the assignment score increases learning hours also increases

# %%
sns.regplot(x="assignment_score",y="total_score",data=df)
plt.title("Distribution of assignment_score compared to total_score")
plt.xlabel("assignment_score")
plt.ylabel("total_score")
plt.show()

# %% [markdown]
# The visualization indicates upward trend in assignment score and total score, which means that there's a positive relationship as the assignment score increases total score also increases.

# %%
sns.regplot(x="project_score",y="total_score",data=df)
plt.title("Distribution of project_score compared to total_score")
plt.xlabel("project_score")
plt.ylabel("total_score")
plt.show()

# %% [markdown]
# The visualization indicates upward trend in project score and total score, which means that there's a positive relationship as the project score increases total score also increases.

# %%
sns.regplot(x="final_rating",y="attendance_pct",data=df)
plt.title("Distribution of final_rating compared to attendance_pct")
plt.xlabel("final_rating")
plt.ylabel("attendance_pct")
plt.show()

# %% [markdown]
# The visualization indicates an upward trend in final rating and attendance percentage, which means that there's a positive relationship as the final rating increases attendance percentage also increases.

# %%
sns.boxplot(x="gender", y="avg_quiz_score", data=df)
plt.title("Distribution of gender Compared to avg_quiz_score")
plt.xlabel("gender")
plt.ylabel("avg_quiz_score")
plt.show()

# %% [markdown]
# The visualization indicates that Male students have highest median of average quiz score and Female students have lowest median

# %%
sns.boxplot(x="gender", y="assignment_score", data=df)
plt.title("Distribution of gender Compared to assignment_score")
plt.xlabel("gender")
plt.ylabel("assignment_score")
plt.show()

# %% [markdown]
# The visualization indicates that Male students have highest median of assignment score and Female students have lowest median

# %%
sns.boxplot(x="city", y="sessions_attended", data=df)
plt.title("Distribution of city Compared to sessions_attended")
plt.xlabel("city")
plt.ylabel("sessions_attended")
plt.show()

# %% [markdown]
# The visualization indicates that Pune city have the highest median of sessions attended followed by Hyderabad. Delhi,Mumbai,Chennai and Bangalore have the lowest median of sessions attended.

# %%
sns.boxplot(x="city", y="avg_quiz_score", data=df)
plt.title("Distribution of city Compared to avg_quiz_score")
plt.xlabel("city")
plt.ylabel("avg_quiz_score")
plt.show()

# %% [markdown]
# The visualization indicates that Chennai have the highest median of average quiz score followed by Mumbai. Hyderabad,Pune,Delhi and Bangalore have the lowest median of average quiz score.

# %%
sns.boxplot(x="city", y="project_score", data=df)
plt.title("Distribution of city Compared to project_score")
plt.xlabel("city")
plt.ylabel("project_score")
plt.show()

# %% [markdown]
# The visualization indicates that Pune city have the highest median of project score followed by Bangalore. Hyderabad,Delhi,Mumbai and Bangalore have the lowest median of project score.

# %%
sns.boxplot(x="batch_type", y="sessions_attended", data=df)
plt.title("Distribution of batch_type Compared to sessions_attended")
plt.xlabel("batch_type")
plt.ylabel("sessions_attended")
plt.show()

# %% [markdown]
# The visualization indicates that weekend batch have the highest median of session attended and weekday batches have lowest median.

# %%
sns.scatterplot(x="learning_hours", y="total_score", hue="learning_intensity", data=df)
plt.title("Scatterplot for analaysing learning_hours and total_score with respect to learning_intensity")
plt.xlabel("learning_hours")
plt.ylabel("total_score")
plt.show()

# %% [markdown]
# The visualization indicates positive relationship between learning hours and total score as the learning hourse increases total score also increases.

# %%
sns.boxplot(x="course",y="final_rating",hue="batch_type",data=df)
plt.title("Boxplot for course and final_rating with respect to batch_type")
plt.xlabel("course")
plt.ylabel("final_rating")
plt.show()

# %% [markdown]
# The visualization indicates that courses like Generative AI and AI & ML have highest median for weekday batches and Data Science and Data Analytics have highest median for weekend batches

# %%
sns.boxplot(x="gender",y="avg_quiz_score",hue="performance",data=df)
plt.title("Boxplot for gender and avg_quiz_score with respect to performance")
plt.xlabel("gender")
plt.ylabel("avg_quiz_score")
plt.show()

# %% [markdown]
# The visualization indicates that male students have highest median score for good performance and few students have Excellent performance.
# The few Female students have Excellent performance.

# %%
sns.boxplot(x="gender",y="total_score",hue="placement_status",data=df)
plt.title("Boxplot for gender and total_score with respect to placement_status")
plt.xlabel("gender")
plt.ylabel("total_score")
plt.show()

# %% [markdown]
# The visualization indicates that male students have highest median score for placed students and Female students have highest median score for not placed students

# %%
ct1 = pd.crosstab(df["course"],df["batch_type"],values=df["final_rating"],aggfunc='mean')
ct1
# Out:
# batch_type       Weekday   Weekend
# course
# AI & ML         3.642231  3.508451
# Data Analytics  3.387391  3.566761
# Data Science    3.533471  3.689524
# Generative AI   3.513655  3.394242

# %%
ct1.plot(kind="bar",figsize=(8,6))
plt.title("Distribution of course wise final rating with respect to batch type")
plt.xlabel("course")
plt.ylabel("Final Rating")
plt.show()

# %% [markdown]
# The visualization shows that AI & ML and Generative AI have highest rating for weekday batches and Data Analytics and Data Science have highest rating for weekend batches.

# %%
ct2 = pd.crosstab(df["city"],df["gender"],values=df["learning_hours"],aggfunc='sum')
ct2
# Out:
# gender     Female  Male
# city
# Bangalore     904   947
# Chennai       694   863
# Delhi         771   702
# Hyderabad    1206   984
# Mumbai       1095  1011
# Pune          925   961

# %%
ct2.plot(kind="bar",figsize=(8,6))
plt.title("Distribution of city wise learning hours with respect to gender")
plt.xlabel("city")
plt.ylabel("Learning Hours")
plt.show()

# %% [markdown]
# The visualization shows that In Delhi, Hyderabad and Mumbai Female students have highest learning hours and in Bangalore, Chennai and Pune Male students have highst learning hours
